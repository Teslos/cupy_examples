# %%
import cupy as cp

# %%
import numpy as np

# %%
array_cpu = np.random.randint(0,255,size=(4000,4000))

# %%
array_cpu.nbytes / 1e6
# Out:
# 64.0

# %%
array_gpu = cp.asarray(array_cpu)

# %%
type(array_gpu)
# Out:
# cupy.ndarray

# %%
from scipy import fft

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\ivt\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\ivt\anaconda3\lib\site-packages (from scipy) (1.26.4)

# %%
# %%timeit
fft.fftn(array_cpu)
# Out:
# 690 ms ± 6.29 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
from cupyx.scipy import fft as fft_gpu

# %%
# %%timeit
fft_gpu.fftn(array_gpu)
# Out:
# The slowest run took 4.82 times longer than the fastest. This could mean that an intermediate result is being cached.
# 185 µs ± 94.5 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
